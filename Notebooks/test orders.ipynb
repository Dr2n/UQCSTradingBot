# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

from ccxtbt import CCXTStore, CCXTFeed
import backtrader as bt
from datetime import datetime, timedelta
import json
import ccxt
import pprint


import argparse

from backtrader.utils import flushfile  # win32 quick stdout flushing
from backtrader.utils.py3 import string_types

# %%
broker_mapping = {
    'order_types': {
        bt.Order.Market: 'market',
        bt.Order.Limit: 'limit',
        bt.Order.Stop: 'stop',
        bt.Order.StopLimit: 'stop limit'
    },
    'mappings':{
        'closed_order':{
            'key': 'status',
            'value':'closed'
        },
        'canceled_order':{
            'key': 'result',
            'value':1}
    }
}

config = {'urls': {'api': 'https://testnet.bitmex.com'},
                   'apiKey': "PUNPhX0cNSinQ7Zv4TRAETdx",
                   'secret': "duc5b9JxLy68Oza_9cfv6I8HztwaYFSOdETWmOYOCojFtGv7",
                   'enableRateLimit': True,
                  }

# %%
exchange = ccxt.bitmex({
    'apiKey': 'PUNPhX0cNSinQ7Zv4TRAETdx',
    'secret': 'duc5b9JxLy68Oza_9cfv6I8HztwaYFSOdETWmOYOCojFtGv7',
})
if 'test' in exchange.urls:
    exchange.urls['api'] = exchange.urls['test'] # ←----- switch the base URL to testnet
pprint.pprint(exchange.fetch_balance())
# Out:
# {'BTC': {'free': 0.00998918, 'total': 0.00998918, 'used': 0.0},
#  'free': {'BTC': 0.00998918},
#  'info': [{'account': 319315,
#            'action': '',
#            'amount': 998918,
#            'availableMargin': 998918,
#            'commission': None,
#            'confirmedDebit': 0,
#            'currency': 'XBt',
#            'excessMargin': 998918,
#            'excessMarginPcnt': 1,
#            'grossComm': 0,
#            'grossExecCost': 0,
#            'grossLastValue': 0,
#            'grossMarkValue': 0,
#            'grossOpenCost': 0,
#            'grossOpenPremium': 0,
#            'indicativeTax': 0,
#            'initMargin': 0,
#            'maintMargin': 0,
#            'marginBalance': 998918,
#            'marginBalancePcnt': 1,
#            'marginLeverage': 0,
#            'marginUsedPcnt': 0,
#            'pendingCredit': 0,
#            'pendingDebit': 0,
#            'prevRealisedPnl': -48663,
#            'prevState': '',
#            'prevUnrealisedPnl': 0,
#            'realisedPnl': 0,
#            'riskLimit': 1000000000000,
#            'riskValue': 0,
#            'sessionMargin': 0,
#            'state': '',
#            'syntheticMargin': None,
#            'targetExcessMargin': 0,
#            'taxableMargin': 0,
#            'timestamp': '2020-09-10T12:00:00.960Z',
#            'unrealisedPnl': 0,
#            'unrealisedProfit': 0,
#            'varMargin': 0,
#            'walletBalance': 998918,
#            'withdrawableMargin': 998918}],
#  'total': {'BTC': 0.00998918},
#  'used': {'BTC': 0.0}}

# %%
cerebro = bt.Cerebro()

# %%
store = CCXTStore(exchange="bitmex", currency="XBt", config=config, retries=5, debug=False, sandbox=True)
store.exchange = exchange

feed = CCXTFeed(store=store)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-20b03be7d588> in <module>
# ----> 1 store = CCXTStore(exchange="bitmex", currency="XBt", config=config, retries=5, debug=False, sandbox=True)
#       2 store.exchange = exchange
#       3
#       4 feed = CCXTFeed(store=store)
#
# ~/.local/lib/python3.6/site-packages/ccxtbt/ccxtstore.py in __call__(cls, *args, **kwargs)
#      43         if cls._singleton is None:
#      44             cls._singleton = (
# ---> 45                 super(MetaSingleton, cls).__call__(*args, **kwargs))
#      46
#      47         return cls._singleton
#
# ~/.local/lib/python3.6/site-packages/backtrader/metabase.py in __call__(cls, *args, **kwargs)
#      86         _obj, args, kwargs = cls.donew(*args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
# ---> 88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
#      89         _obj, args, kwargs = cls.dopostinit(_obj, *args, **kwargs)
#      90         return _obj
#
# ~/.local/lib/python3.6/site-packages/backtrader/metabase.py in doinit(cls, _obj, *args, **kwargs)
#      76
#      77     def doinit(cls, _obj, *args, **kwargs):
# ---> 78         _obj.__init__(*args, **kwargs)
#      79         return _obj, args, kwargs
#      80
#
# ~/.local/lib/python3.6/site-packages/ccxtbt/ccxtstore.py in __init__(self, exchange, currency, config, retries, debug, sandbox)
#     105         balance = self.exchange.fetch_balance() if 'secret' in config else 0
#     106
# --> 107         if balance == 0 or not balance['free'][currency]:
#     108             self._cash = 0
#     109         else:
#
# KeyError: 'XBt'

# %%
hist_start_date = datetime.utcnow() - timedelta(minutes=1000)
data1 = CCXTFeed(exchange=exchange,
                         dataname="ETH/USD",
                         timeframe=bt.TimeFrame.Minutes,
                         fromdate=datetime(2019, 1, 1, 0, 2),
                         todate=datetime(2019, 1, 3, 0, 2),
                         compression=1,
                         ohlcv_limit=2,
                         currency='BTC',
                         retries=5,

                         # 'apiKey' and 'secret' are skipped
                         config=config)

class MyCSVData(bt.feeds.GenericCSVData):
    params = (
        ('dtformat', '%Y-%m-%d %H:%M'),
        ('tmformat', '%H%M'),

        ('datetime', 0),
        ('symbol', 1),
        ('open', 2),
        ('high', 3),
        ('low', 4),
        ('close', 5),
        ('volume', 6),
        ('openinterest', -1))
    

data2 = MyCSVData(
            dataname="XBTUSD-1m-data.csv"),
            # Do not pass values before this date
            fromdate=Strategy.params.start_date,
            # Do not pass values before this date
            todate=Strategy.params.end_date,
            # Do not pass values after this date
            reverse=False,
            tzinput=Strategy.params.timezone)

# %%
broker = store.getbroker(broker_mapping=broker_mapping)
cerebro.setbroker(broker)
class TestStrategy(bt.Strategy):
    def __init__(self):
        self.next_runs = 0

    def next(self, dt=None):
        dt = dt or self.datas[0].datetime.datetime(0)
        print('%s closing price: %s' % (dt.isoformat(), self.datas[0].close[0]))
        self.next_runs += 1
# Get our data
# Drop newest will prevent us from loading partial data from incomplete candles
hist_start_date = datetime.utcnow() - timedelta(minutes=50)
data = store.getdata(dataname='XBt/USD', name="ETHUSD",
                     timeframe=bt.TimeFrame.Minutes, 
                     fromdate=datetime(2019, 1, 1, 0, 2),
                     todate=datetime(2019, 1, 3, 0, 2),
                     compression=1, ohlcv_limit=50, drop_newest=True )#, historical=True)

#cerebro.adddata(data1)
cerebro.adddata(data1)
cerebro.addstrategy(TestStrategy)
cerebro.run()
# Out:
# 2019-01-01T00:02:00 closing price: 131.15
# 2019-01-01T00:03:00 closing price: 131.15
# 2019-01-01T00:04:00 closing price: 131.15
# 2019-01-01T00:05:00 closing price: 131.15
# 2019-01-01T00:06:00 closing price: 131.15
# 2019-01-01T00:07:00 closing price: 131.15
# 2019-01-01T00:08:00 closing price: 131.15
# 2019-01-01T00:09:00 closing price: 131.1
# 2019-01-01T00:10:00 closing price: 131.1
# 2019-01-01T00:11:00 closing price: 131.1
# 2019-01-01T00:12:00 closing price: 131.1
# 2019-01-01T00:13:00 closing price: 131.1
# 2019-01-01T00:14:00 closing price: 131.1
# 2019-01-01T00:15:00 closing price: 131.1
# 2019-01-01T00:16:00 closing price: 131.1
# 2019-01-01T00:17:00 closing price: 131.1
# 2019-01-01T00:18:00 closing price: 131.1
# 2019-01-01T00:19:00 closing price: 131.1
# 2019-01-01T00:20:00 closing price: 131.1
# 2019-01-01T00:21:00 closing price: 131.1
# 2019-01-01T00:22:00 closing price: 131.1
# 2019-01-01T00:23:00 closing price: 131.1
# 2019-01-01T00:24:00 closing price: 131.15
# 2019-01-01T00:25:00 closing price: 131.15
# 2019-01-01T00:26:00 closing price: 131.15
# 2019-01-01T00:27:00 closing price: 131.1
# 2019-01-01T00:28:00 closing price: 131.1
# 2019-01-01T00:29:00 closing price: 131.1
# 2019-01-01T00:30:00 closing price: 131.15
# 2019-01-01T00:31:00 closing price: 131.15
# 2019-01-01T00:32:00 closing price: 131.15
# 2019-01-01T00:33:00 closing price: 131.15
# 2019-01-01T00:34:00 closing price: 131.15
# 2019-01-01T00:35:00 closing price: 131.1
# 2019-01-01T00:36:00 closing price: 131.15
# 2019-01-01T00:37:00 closing price: 131.1
# 2019-01-01T00:38:00 closing price: 131.1
# 2019-01-01T00:39:00 closing price: 131.1
# 2019-01-01T00:40:00 closing price: 131.1
# 2019-01-01T00:41:00 closing price: 131.1
# 2019-01-01T00:42:00 closing price: 131.1
# 2019-01-01T00:43:00 closing price: 131.1
# 2019-01-01T00:44:00 closing price: 131.1
# 2019-01-01T00:45:00 closing price: 131.1
# 2019-01-01T00:46:00 closing price: 131.1
# 2019-01-01T00:47:00 closing price: 131.1
# 2019-01-01T00:48:00 closing price: 131.15
# 2019-01-01T00:49:00 closing price: 131.15
# 2019-01-01T00:50:00 closing price: 131.15
# 2019-01-01T00:51:00 closing price: 131.1
# 2019-01-01T00:52:00 closing price: 131.15
# 2019-01-01T00:53:00 closing price: 131.15
# 2019-01-01T00:54:00 closing price: 131.1
# 2019-01-01T00:55:00 closing price: 131.1
# 2019-01-01T00:56:00 closing price: 131.1
# 2019-01-01T00:57:00 closing price: 131.15
# 2019-01-01T00:58:00 closing price: 131.15
# 2019-01-01T00:59:00 closing price: 131.1
# 2019-01-01T01:00:00 closing price: 131.1
# 2019-01-01T01:01:00 closing price: 131.15
# 2019-01-01T01:02:00 closing price: 131.15
# 2019-01-01T01:03:00 closing price: 131.1
# 2019-01-01T01:04:00 closing price: 131.1
# 2019-01-01T01:05:00 closing price: 131.1
# 2019-01-01T01:06:00 closing price: 131.1
# 2019-01-01T01:07:00 closing price: 131.15
# 2019-01-01T01:08:00 closing price: 131.15
# 2019-01-01T01:09:00 closing price: 131.15
# 2019-01-01T01:10:00 closing price: 131.15
# 2019-01-01T01:11:00 closing price: 131.15
# 2019-01-01T01:12:00 closing price: 131.15
# 2019-01-01T01:13:00 closing price: 131.15
# 2019-01-01T01:14:00 closing price: 131.15
# 2019-01-01T01:15:00 closing price: 131.1
# 2019-01-01T01:16:00 closing price: 131.1
# 2019-01-01T01:17:00 closing price: 131.1
# 2019-01-01T01:18:00 closing price: 131.15
# 2019-01-01T01:19:00 closing price: 131.15
# 2019-01-01T01:20:00 closing price: 131.15
# 2019-01-01T01:21:00 closing price: 131.15
# 2019-01-01T01:22:00 closing price: 131.15
# 2019-01-01T01:23:00 closing price: 131.15
# 2019-01-01T01:24:00 closing price: 131.15
# 2019-01-01T01:25:00 closing price: 131.15
# 2019-01-01T01:26:00 closing price: 131.15
